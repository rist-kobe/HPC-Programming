# %% [markdown]
# <a href="https://colab.research.google.com/github/KengoMiyamoto/ScalarProgramming/blob/main/sample_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scalar Programming - Sample Code
#
# This notebook demonstrates scalar programming concepts using the HPC-Programming repository.

# %% [markdown]
# ## Setup

# %% [markdown]
# Get GNU Fortran and NVIDIA HPC SDK (~30-min)

# %%
# !apt-get install -y gfortran
# !echo 'deb [trusted=yes] https://developer.download.nvidia.com/hpc-sdk/ubuntu/amd64 /' | sudo tee /etc/apt/sources.list.d/nvhpc.list
# !sudo apt-get update -y
# !sudo apt-get install -y nvhpc-22-7-cuda-multi

import os

os.environ['PATH'] = (
    '/opt/nvidia/hpc_sdk/Linux_x86_64/22.7/compilers/bin:'
    + os.environ['PATH']
)

# %% [markdown]
# Clone the HPC-Programming repository from rist-kobe and set HPC-Programming/Tuning/sample_code as the working directory.

# %%
# %cd /content
# !git clone https://github.com/rist-kobe/HPC-Programming.git
# %cd HPC-Programming/Tuning/sample_code
# !ls

# %% [markdown]
# ## Run
#
# Execute all of the C language sample programs, one by one, with the default settings.

# %% [markdown]
# 01_timer

# %%
# %cd /content/HPC-Programming/Tuning/sample_code/01_timer
# %pushd src/c
# !echo
# !bash -x -c "make veryclean; make; ls"
# !echo
# %popd
# %pushd tests/c
# !echo
# !bash -x -c "ls"
# !echo
# !bash -x -c "./run.sh"
# !echo
# !bash -x -c "cat outfile"
# !echo
# %popd
